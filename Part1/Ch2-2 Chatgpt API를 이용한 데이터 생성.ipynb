# %% [markdown]
# # **1.Setting**

# %%
# openai 라이브러리 설치
! pip install openai

# openai 라이브러리 가져오기
import openai

# client 객체 생성 > Chatgpt API 사용 
client=openai.OpenAI(api_key="")
# Out:
# Requirement already satisfied: openai in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.2.0)
# Requirement already satisfied: anyio<5,>=4.10.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (2.10.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openai) (4.16.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5,>=4.10.0->openai) (3.19)
# Requirement already satisfied: httpcore2==2.10.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx2<3,>=2.7.0->openai) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx2<3,>=2.7.0->openai) (0.10.4)
# Requirement already satisfied: h11>=0.16 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore2==2.10.0->httpx2<3,>=2.7.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.4)
# Requirement already satisfied: colorama in C:\Users\오소민\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tqdm>4->openai) (0.4.6)

# %% [markdown]
# # **2.Answer**

# %%
# system prompt : LLM에게 원하는 역할
# user prompt: LLM에게 현재 하고 있는 질문 
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "너는 현재 가장 잘 나가는 야구 중계 유튜버야. 답변은 공손하게 해줘"},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어? "}
    ]
)

# 답변 얻기
print(response.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 LA 다저스가 우승했습니다. 탬파베이 레이스를 상대로 4승 2패로 승리를 거두며 월드시리즈 트로피를 차지했죠. 질문해 주셔서 감사합니다! 더 궁금한 점이 있으면 언제든지 물어보세요.

# %%
# system prompt : LLM에게 원하는 역할
# user prompt: LLM에게 현재 하고 있는 질문 
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "사용자의 질문에 답변을 하지말고 한글 질문을 영어로 번역하십시오"},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어? "}
    ]
)

# 답변 얻기
print(response.choices[0].message.content)
# Out:
# Who won the World Series in 2020?

# %%
# 이전 대화를 포함하여 답변하기
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"},
        {"role": "assistant", "content": "바로 예상을 뚫고 4강 진출 신화를 일으킨 한국입니다."},
        {"role": "user", "content": "그 나라가 화제가 되었던 이유를 자세하게 설명해줘."}
    ]
)

print(response.choices[0].message.content)
# Out:
# 2002년 월드컵에서 한국이 화제가 되었던 이유는 여러 가지가 있습니다:
#
# 1. **4강 진출**: 한국은 2002년 월드컵에서 처음으로 4강에 진출했습니다. 이는 아시아 국가로서는 전례가 없는 성과로, 많은 이들에게 충격적이고 놀라운 결과였습니다. 한국은 폴란드와 포르투갈을 꺾고 조별리그를 통과했으며, 16강에서는 이탈리아, 8강에서는 스페인을 꺾는 이변을 연출했습니다.
#
# 2. **공동 개최국**: 한국은 일본과 함께 월드컵을 공동 개최했으며, 이는 월드컵 역사상 최초의 공동 개최였습니다. 이는 전 세계의 주목을 받는 중요한 이벤트였습니다.
#
# 3. **히딩크 감독**: 거스 히딩크 감독의 지도 아래 한국 팀은 체계적이고 효과적인 경기 운영을 보여주며 많은 사람들의 인정을 받았습니다. 히딩크의 지도력은 한국 축구의 발전에도 큰 영향을 미쳤습니다.
#
# 4. **열정적인 팬과 문화**: 한국 팬들의 열정적인 응원과 붉은 악마로 대표되는 서포터 문화는 전 세계적으로 큰 주목을 받았습니다. 거리 응원과 같은 독특한 응원 문화는 스포츠 행사에서 팬 참여의 새로운 기준을 제시했습니다.
#
# 5. **주최국 이점**: 개최국으로서 한국은 인프라, 경기장, 지역 사회의 준비 상태 등에서 긍정적인 평가를 받았습니다. 또한, 홈 어드밴티지를 잘 활용하며 좋은 경기력을 보여주었습니다.
#
# 이러한 요소들이 결합되어 한국은 2002년 월드컵에서 세계적으로 많은 주목을 받았습니다.

# %% [markdown]
# # **3.Practice**

# %% [markdown]
# ```
# response = client.chat.completions.create(
#   model="gpt-4o",
#   messages=[
#         {"role": "system", "content": "<정해주고 싶은 역할>"},
#         {"role": "user", "content": "<작성하고 싶은 Prompt>"}
#     ]
# )
# ```

# %%
# System prompt: 전반적인 지시사항 입력 (어떻게 행동할 것인가?)
# User prompt : 텍스트 입력값 (입력 데이터는 무엇인가?)
def return_answer(input_text=''):
    system_prompt = """특정 문서가 입력되면 다음과 같은 형태로 문서를 분석하십시오.

1. 주어진 입력:에 대해서 반드시 주제:, 요약:, 가능한 질문: 이 세가지를 순차적으로 작성해야 합니다.
2. 주제:는 입력 문서의 주제를 한 줄로 요약합니다.
3. 요약:은 입력 문서를 5줄로 요약합니다.
4. 가능한 질문:은 입력 문서로부부터 사람들이 할 수 있는 질문 세 가지를 파이썬 리스트 형태로 작성합니다.
5. 가능한 질문:이 반드시 ["질문1", "질문2", "질문3"]과 같이 파이썬 리스트 형태로 작성되어야 하는 점에 유의하십시오.

이제 시작합니다."""
    
    # 답변을 전달해주는 형식
    user_content = "입력: "+ input_text + "\n답변:"
    
    print('최종 유저 프롬프트')
    print('==' * 50)
    print(user_content)

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_content}
        ]
    )

    return response.choices[0].message.content



# 예시 샘플 입력
test = '''새처럼 움직이는 항공 로봇 '레이븐'.

스위스 로잔 연방 공대(EPFL) 신원동 박사팀이 개발했는데요.

연구팀은 새의 엉덩이와 발목, 발을 참고해 뒷다리를 만들었습니다.

실제 새처럼 땅에서 걷고, 틈새를 건너뛰고, 위로 뛰어오릅니다.

껑충 뛰면서 날아오르는 이 기능이 핵심인데요.

기존 고정익 항공기처럼 지상을 달리지 않고 제자리에서 날아오릅니다.

연구팀은 레이븐의 점프 이륙이 점프하지 않고 날아오를 때보다 에너지 효율이 더 높다고 설명했는데요.

또 기존 고정익 항공기에 이 기능을 도입하면 복잡한 지형에서도 효율적으로 쓸 수 있을 거라고 덧붙였습니다.

#새 #로봇 #항공 #공대 #스위스 #신원동 #박사 #점프'''

# 실제 실행
result = return_answer(test)
print(result)
# Out:
# 최종 유저 프롬프트
# ====================================================================================================
# 입력: 새처럼 움직이는 항공 로봇 '레이븐'.
#
# 스위스 로잔 연방 공대(EPFL) 신원동 박사팀이 개발했는데요.
#
# 연구팀은 새의 엉덩이와 발목, 발을 참고해 뒷다리를 만들었습니다.
#
# 실제 새처럼 땅에서 걷고, 틈새를 건너뛰고, 위로 뛰어오릅니다.
#
# 껑충 뛰면서 날아오르는 이 기능이 핵심인데요.
#
# 기존 고정익 항공기처럼 지상을 달리지 않고 제자리에서 날아오릅니다.
#
# 연구팀은 레이븐의 점프 이륙이 점프하지 않고 날아오를 때보다 에너지 효율이 더 높다고 설명했는데요.
#
# 또 기존 고정익 항공기에 이 기능을 도입하면 복잡한 지형에서도 효율적으로 쓸 수 있을 거라고 덧붙였습니다.
#
# #새 #로봇 #항공 #공대 #스위스 #신원동 #박사 #점프
# 답변:
# 주제: 새의 움직임을 모방한 항공 로봇 '레이븐'의 개발과 장점
#
# 요약: 스위스 로잔 연방 공대의 신원동 박사팀이 새처럼 움직이는 항공 로봇 '레이븐'을 개발했습니다. 레이븐은 새의 엉덩이, 발목, 발을 모방하여 뒷다리를 만들었고, 실제 새처럼 걷고 점프하며 날 수 있습니다. 이 로봇은 기존 고정익 항공기처럼 지상을 달리지 않고 제자리에서 날아오르며, 점프 이륙 방식이 에너지 효율이 더 높다고 연구팀은 밝혔습니다. 또, 이러한 기능은 항공기에 도입되어 복잡한 지형에서도 효율적으로 활용될 수 있을 것으로 기대됩니다.
#
# 가능한 질문: ["레이븐은 어떻게 새의 움직임을 모방했나요?", "점프 이륙 방식이 기존 방식을 어떻게 개선하나요?", "레이븐의 기능이 항공 산업에 어떻게 응용될 수 있을까요?"]
